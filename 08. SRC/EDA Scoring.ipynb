# %%
import os
import re
import glob
import pickle
import numpy as np
import pandas as pd
import pandas.io.common
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#### File Path and Variables
loc_path = r'/Users/raj2.gaurav/Desktop/' 
path = loc_path + r'/supervised_classification/06. Inference Data/'
pickle_path = loc_path + '/supervised_classification/06. Inference Data/'

# %%
## Pre Processing
def remove_whitespaces(df):
    df_obj = df.select_dtypes(['object'])
    df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
    df.columns = df.columns.str.strip()
    return df

def drop_duplicate_records(df):
    df.drop_duplicates()
    return df

#### Collating Files 


allFiles = glob.glob(path + "/*.csv")
lst=[]
df_master=pd.DataFrame()
for i in allFiles:
    df=pd.read_csv(i)
    #print(df.shape)
    df_master=df_master.append(df)
    #print(df_master.shape)

# %%
df.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  Scientist      19114.12            1824.843333                  3
# 1  Scientist      19114.12            1824.843333                  3
# 2  Scientist      19114.12            1824.843333                  3
# 3  Scientist      19114.12                    NaN                  3
# 4    _______      34847.84            3037.986667                  2
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# ...

# %%
df.shape
# Out:
# (50000, 27)

# %%
df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
Null_col_data=(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
col_to_drop=Null_col_data[Null_col_data>40].keys()
df_ml=df.drop(col_to_drop,axis=1)

# %%
df_ml.shape
# Out:
# (50000, 27)

# %%
df_ml.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %% [markdown]
# ### TREATING NULL VALUES

# %%
for i in df_ml.columns:
    if df_ml[i].dtypes=='int64'  or df_ml[i].dtypes=='float64':
        df_ml[i].fillna(df_ml[i].mean(),inplace=True)
        
    else:
        df_ml[i].fillna(df_ml[i].mode(),inplace=True)

# %%
df_ml.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries           0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
def Month_Converter(x):
    if pd.notnull(x):
        num1 = int(x.split(' ')[0])
        num2 = int(x.split(' ')[3])
      
        return (num1*12)+num2
    else:
        return x
    
# Month_Converter('3 Years and 1 Months')

# %%
df_ml['Credit_History_Age'] = df_ml.Credit_History_Age.apply(lambda x: Month_Converter(x)).astype(float)

# %%
df_ml.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  Scientist      19114.12            1824.843333                  3
# 1  Scientist      19114.12            1824.843333                  3
# 2  Scientist      19114.12            1824.843333                  3
# 3  Scientist      19114.12            4182.004291                  3
# 4    _______      34847.84            3037.986667                  2
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# ...

# %%
# Revise the incorrect data whole table
sym = "\\`*_{}[]()>#@+!''$:;-_"
col_int = ['Age','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt',
           'Total_EMI_per_month','Monthly_Balance','Annual_Income','Num_of_Loan','Changed_Credit_Limit','Amount_invested_monthly']
col_str = ['Occupation','Credit_History_Age','Payment_of_Min_Amount']
for i in col_int:
    for c in sym:
        df_ml[i] = df_ml[i].astype(str).str.replace(c,'')
for i in col_str:
    for c in sym:
        df_ml[i] = df_ml[i].replace(c,'')
df_ml.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh  24  821-00-0265  Scientist
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12            1824.843333                  3                4
# 1      19114.12            1824.843333                  3                4
# 2      19114.12            1824.843333                  3                4
# 3      19114.12            4182.004291                  3                4
# 4      34847.84            3037.986667                  2                4
#
#    Interest_Rate Num_of_Loan  \
# ...

# %%
df_ml.dtypes

# %%
df_ml['Changed_Credit_Limit'].unique()
# Out:
# array(['11.27', '', '6.27', ..., '17.509999999999998', '25.16', '21.17'],
#       dtype=object)

# %%
df_ml['Annual_Income']=df_ml['Annual_Income'].astype('float')
df_ml['Num_of_Loan']=df_ml['Num_of_Loan'].astype('int')
df_ml['Num_of_Delayed_Payment']=df_ml['Num_of_Delayed_Payment'].astype('float')
# df_ml['Changed_Credit_Limit']=df_ml['Changed_Credit_Limit'].astype('float')
df_ml['Outstanding_Debt']=df_ml['Outstanding_Debt'].astype('float')
df_ml['Amount_invested_monthly']=df_ml['Amount_invested_monthly'].astype('float')
df_ml['Monthly_Balance']=df_ml['Monthly_Balance'].astype('float')

# %%
pickle_path
# Out:
# '/Users/raj2.gaurav/Desktop//supervised_classification/06. Inference Data/'

# %%
#### SAVING PROCEESED DATA
df_ml.to_pickle(pickle_path+ 'Pre_Processed_Scoring_Causal_Data.pickle')
