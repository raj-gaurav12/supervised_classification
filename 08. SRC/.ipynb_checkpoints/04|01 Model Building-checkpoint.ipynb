# %%
# Databricks notebook source
import os
import re
import gc
import glob
import pickle
import warnings
import os.path
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm
import pandas.io.common
from scipy import stats
from datetime import datetime
from scipy.special import inv_boxcox
# from catboost.utils import eval_metric
# from catboost import CatBoostRegressor,Pool
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
loc_path = r'/Users/raj2.gaurav/Desktop/' 
ADS_features_path = loc_path + 'Causal Model/05. Training Data/'
df = pd.read_csv(ADS_features_path + 'ADS_Bihar_Nov.csv')

# %%
df.head()
# Out:
#   Circle     City  Component Partition_date  Hour  Total customers  \
# 0  bihar  deoghar         33     2022-11-06     5             4726
# 1  bihar  deoghar         33     2022-11-06     6             6551
# 2  bihar  katihar        116     2022-11-06    11            13276
# 3  bihar  katihar        116     2022-11-06    12            14047
# 4  bihar    patna         85     2022-11-06     7            11028
#
#          Anomaly  Ratio data  Ratio voice  Ratio hsi Cluster_issue  \
# 0         Voice            1            4          2           NaN
# 1         Voice            1            3          2           NaN
# 2           HSI            2            2          4      high_prb
# 3           HSI            2            2          4      high_prb
# 4  Data - Voice            4            3          0           NaN
#
#    Data volume  Data volume formula  Data volume mean  Data volume std  \
# 0           27                   49                16               10
# 1           47                   85                27               19
# 2          137                  191                46               48
# 3          141                  197                47               49
# 4          166                  129                35               31
#
#    Voice affected users  Voice affected users formula  \
# 0                   267                           223
# 1                   499                           495
# 2                   888                          1478
# 3                   851                          1454
# 4                   991                           887
#
#    Voice affected users mean  Voice affected users std  Hsi affected users  \
# 0                         62                        53                  65
# 1                        144                       116                 160
# 2                        352                       375                1533
# 3                        342                       370                1656
# 4                        252                       211                 113
#
#    Hsi affected users formula  Hsi affected users mean  \
# 0                         223                       25
# 1                         447                       73
# 2                        1532                      337
# 3                        1616                      351
# 4                         674                      131
#
#    Hsi affected users std  Num_grids  Num_cells  Num_sectors  \
# 0                      66          9         35           10
# 1                     124          9         35           10
# 2                     398          8         27            8
# 3                     421          8         27            8
# 4                     180         13         60           19
#
#    Indoor frqeqency % 850  Indoor frqeqency % 1800  Indoor frqeqency % 2300  \
# 0                      31                       31                       36
# 1                      35                       31                       33
# 2                      32                       39                       27
# 3                      33                       40                       26
# 4                      30                       31                       38
#
#    Prb_10  Prb_10_25  Prb_25_70  Prb_70_90  Prb_90  Target_Cluster  \
# 0    9.00      22.00       4.00       0.00    0.00               0
# 1    6.00      19.00      10.00       0.00    0.00               0
# 2    0.00       0.00       8.00       8.00   11.00               1
# 3    0.00       0.00       7.00      10.00   10.00               1
# 4    0.00      11.00      41.00       5.00    3.00               0
#
#    Sum_total_volume_mb_download  Sum_total_volume_mb_upload  Unique_customers  \
# 0                12416679610.00                849541683.00           1393.00
# 1                22920760951.00               2194595046.00           1808.00
# 2                38271955206.00               3384246507.00           2182.00
# 3                43646120543.00               3608188983.00           2094.00
# 4                49107207869.00               4211397132.00           3595.00
#
#    Total_duration_sec  Total_sessions    Rsrp_nom  Rsrp_dnom   Rsrq_nom  \
# 0           457966.00        16223.00  -852588.00    8767.00  -93934.00
# 1           651638.00        20006.00 -1077896.00   11200.00 -127212.00
# 2           500347.00        25844.00 -1520924.00   15271.00 -213869.00
# 3           480070.00        26834.00 -1679304.00   16734.00 -232907.00
# 4          1627912.00        50063.00 -2857620.00   29925.00 -379860.50
#
#    Rsrq_dnom  Mean_cqi_nom  Mean_cqi_dnom  Pusch_sinr_nom  Pusch_sinr_dnom  \
# 0    8767.00     172773.00       16154.00       243832.40         15323.00
# 1   11200.00     206115.00       19937.00       287435.70         18246.00
# 2   15271.00     247706.00       25724.00       118385.60          8936.00
# 3   16734.00     252646.00       26701.00       110929.50          8704.00
# 4   29925.00     458375.00       49864.00       393226.90         35822.00
#
#    Ta_distance_nom  Ta_distance_dnom  Intersite_distance_nom  \
# 0       6892183.00          16223.00              8839869.00
# 1       7775528.00          20006.00             10909146.00
# 2      16869064.00          25844.00             44695061.00
# 3      17197404.00          26834.00             44264376.00
# 4      24208274.00          50063.00             35345652.00
#
#    Intersite_distance_dnom  Rsrp_nom_lag_1_day  Rsrp_dnom_lag_1_day  \
# 0                 16223.00          -852588.00              8767.00
# 1                 20006.00         -1077896.00             11200.00
# 2                 25844.00         -1520924.00             15271.00
# 3                 26834.00         -1679304.00             16734.00
# 4                 50063.00         -2857620.00             29925.00
#
#    Rsrq_nom_lag_1_day  Rsrq_dnom_lag_1_day  Avg_bad_hsi_pct_x  \
# 0           -93934.00              8767.00               9.84
# 1          -127212.00             11200.00               9.34
# 2          -213869.00             15271.00               0.94
# 3          -232907.00             16734.00               7.23
# 4          -379860.50             29925.00              10.52
#
#    Avg_bad_voice_pct_x  Avg_bad_hsi_pct_y  Avg_bad_voice_pct_y
# 0                19.86               9.84                19.86
# 1                21.39               9.34                21.39
# 2                43.54               0.94                43.54
# 3                11.55               7.23                11.55
# 4                14.38              10.52                14.38
